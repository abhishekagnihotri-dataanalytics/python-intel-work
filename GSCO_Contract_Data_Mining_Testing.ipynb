# %%
import pandas as pd
import pyodbc
import numpy as np

# %%
# Import data from SQL Server database
sql_conn = pyodbc.connect('DRIVER={SQL Server};\
                            SERVER=sql1944-fm1-in.amr.corp.intel.com,3181;\
                            DATABASE=GSMDW_TST;\
                            Trusted_Connection=yes;\
                            integrated security=true')

query= """select A.spn,A.line_net_prc_USD_amt,S.glbl_busns_org_prty_id as supl_id
from (
SELECT distinct [supl_id],[supl_mtrl_id] as spn,line_net_prc_USD_amt
FROM [gsmdw_tst].[JUSTIN].[CDM_OA]
UNION
SELECT distinct [curr_supl_id],[curr_supl_itm_nbr],[new_buy_prc_usd_amt]
FROM [gsmdw_tst].[JUSTIN].[CDM_WIINGS]
) A
left join [gsmdw_tst].[JUSTIN].[SuplHier] as S
ON (A.supl_id = S.busns_org_prty_id)
where A.supl_id is not null
and A.line_net_prc_USD_amt is not null
and A.spn is not null"""
df_System = pd.read_sql(query, sql_conn)
sql_conn.close()

# %%
# Import data from SQL Server database
sql_conn = pyodbc.connect('DRIVER={SQL Server};\
                            SERVER=azscia01.amr.corp.intel.com,1433;\
                            DATABASE=CDM;\
                            Trusted_Connection=yes;\
                            integrated security=true')

query= """SELECT C.[Supplier Id]
      ,T.[DocumentId]
      ,T.[TableNumber]
      ,T.[RowNumber]
      ,T.[ColumnNumber]
      ,T.[ColumnValue]
      ,T.[TableConfidence]
  FROM [CDM].[dbo].[tablesunpivoted] AS T
  JOIN [dbo].[draftpublishedcontracts] AS C
  ON C.[Document Id] = T.DocumentId
  WHERE C.[Doc Status] IN ('Published','Draft')"""
df_Contract = pd.read_sql(query, sql_conn)
sql_conn.close()

# %%
# Import data from SQL Server database
sql_conn = pyodbc.connect('DRIVER={SQL Server};\
                            SERVER=sql1944-fm1-in.amr.corp.intel.com,3181;\
                            DATABASE=GSMDW_TST;\
                            Trusted_Connection=yes;\
                            integrated security=true')

query= """select [busns_org_prty_id],[glbl_busns_org_prty_id]
from [gsmdw_tst].[JUSTIN].[SuplHier]"""
df_SuplHier = pd.read_sql(query, sql_conn)
sql_conn.close()

# %%
df_System['supl_id'] = df_System['supl_id'].astype(str)
df_SuplHier['busns_org_prty_id'] = df_SuplHier['busns_org_prty_id'].astype(str)

df_Contract = pd.merge(df_Contract,
                       df_SuplHier,
                       left_on=['Supplier Id'],
                       right_on=['busns_org_prty_id'],
                       how='inner')

# %%
df_System['supl_id'] = df_System['supl_id'].astype(str)
df_System['spn'] = df_System['spn'].str.strip()
df_Contract['busns_org_prty_id'] = df_Contract['busns_org_prty_id'].astype(str)
df_Contract['ColumnValue'] = df_Contract['ColumnValue'].str.strip()
df_Merge = pd.merge(df_System,
                    df_Contract,
                    left_on=['supl_id','spn'],
                    right_on=['busns_org_prty_id','ColumnValue'],
                    how='inner')

#df_Merge = pd.merge(df_System,
#                    df_Contract,
#                    left_on=['spn'],
#                    right_on=['ColumnValue'],
#                    how='inner')

# %%
df_ContractTable = pd.merge(df_Contract,
                            df_Merge,
                            left_on=['DocumentId','TableNumber','RowNumber'],
                            right_on=['DocumentId','TableNumber','RowNumber'],how='left')

# %%
def is_number(nbr):
    try:
        float(nbr)
        return True
    except ValueError:
        return False

def clean(unclean):
    unclean = unclean.replace('$', '')
    unclean = unclean.replace(',','')
    unclean = unclean.strip()
    if is_number(unclean):
        unclean = float(unclean)
    return unclean

# %%
df_ContractTable['Value_clean'] = df_ContractTable.ColumnValue_x.apply(lambda x : clean(x))

# %%
df_ContractTable['Label'] = np.where(df_ContractTable['line_net_prc_USD_amt'].astype(str) == df_ContractTable['Value_clean'].astype(str), 'Price', 'NotPrice')
df_training = df_ContractTable[['DocumentId','TableNumber','ColumnNumber_x','ColumnValue_x','Label']]
df_training.rename(columns={'ColumnNumber_x':'ColumnNumber','ColumnValue_x':'ColumnValue'}, inplace=True)
df_training
# Out:
# C:\Users\jrstrong\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#             DocumentId  TableNumber  ColumnNumber  \
# 0        Doc1000015244            0             0
# 1        Doc1000015244            0             1
# 2        Doc1000015244            0             0
# 3        Doc1000015244            0             1
# 4        Doc1000015244            0             0
# 5        Doc1000015244            0             1
# 6        Doc1000015244            1             0
# 7        Doc1000015244            1             1
# 8        Doc1000015244            1             2
# 9        Doc1000015244            1             3
# 10       Doc1000015244            1             4
# 11       Doc1000015244            1             5
# 12       Doc1000015244            1             6
# 13       Doc1000015244            1             7
# 14       Doc1000015244            1             8
# 15       Doc1000015244            1             9
# 16       Doc1000015244            1            10
# 17       Doc1000015244            1            11
# 18       Doc1000015244            1            12
# 19       Doc1000015244            1            13
# 20       Doc1000015244            1             0
# 21       Doc1000015244            1             1
# 22       Doc1000015244            1             2
# 23       Doc1000015244            1             3
# 24       Doc1000015244            1             4
# 25       Doc1000015244            1             5
# 26       Doc1000015244            1             6
# 27       Doc1000015244            1             7
# 28       Doc1000015244            1             8
# 29       Doc1000015244            1             9
# ...                ...          ...           ...
# 9386756  Doc2104230943            6             6
# 9386757  Doc2104230943            7             0
# 9386758  Doc2104230943            7             1
# 9386759  Doc2104230943            7             2
# 9386760  Doc2104230943            7             0
# 9386761  Doc2104230943            7             1
# 9386762  Doc2104230943            7             2
# 9386763  Doc2104230943            7             0
# 9386764  Doc2104230943            7             1
# 9386765  Doc2104230943            7             2
# 9386766   Doc416552746            0             0
# 9386767   Doc416552746            0             1
# 9386768   Doc416552746            0             2
# 9386769   Doc416552746            0             3
# 9386770   Doc416552746            0             4
# 9386771   Doc416552746            0             0
# 9386772   Doc416552746            0             1
# 9386773   Doc416552746            0             2
# 9386774   Doc416552746            0             3
# 9386775   Doc416552746            0             4
# 9386776   Doc416552746            0             0
# 9386777   Doc416552746            0             1
# 9386778   Doc416552746            0             2
# 9386779   Doc416552746            0             3
# 9386780   Doc416552746            0             4
# 9386781   Doc416552746            0             0
# 9386782   Doc416552746            0             1
# 9386783   Doc416552746            0             2
# 9386784   Doc416552746            0             3
# 9386785   Doc416552746            0             4
#
#                                                ColumnValue     Label
# 0                                                      BY:  NotPrice
# 1                                                      BY:  NotPrice
# 2                                                    NAME:  NotPrice
# 3                                                    NAME:  NotPrice
# 4                                                   TITLE:  NotPrice
# 5                                                   TITLE:  NotPrice
# 6                                         Equipment\nModel  NotPrice
# 7                                 Material\nMaster\nNumber  NotPrice
# 8                            Material\nMaster\nDescription  NotPrice
# 9                                                     CEID  NotPrice
# 10                                                P-\nSpec  NotPrice
# 11                                                C-\nSPEC  NotPrice
# 12          Pricing\nStructureDis\ncount (capital\nspends)  NotPrice
# 13                     Contract\nPrice\n(currency\nsymbol)  NotPrice
# 14          Pre-fac Tender\nprior to\nEquiment STD\n(Days)  NotPrice
# 15                               Forecast\nNotice in\nDays  NotPrice
# 16                          Forecasted\nLead Time\nin Days  NotPrice
# 17                        Unforecasted\nLead Time in\nDays  NotPrice
# 18                                              Expiration  NotPrice
# 19                                                Comments  NotPrice
# 20                                             Synergis MX  NotPrice
# 21                                                     TBD  NotPrice
# 22                                                     TBD  NotPrice
# 23                                                     ABV  NotPrice
# 24                                              06P-\n1944  NotPrice
# 25                                              06C-\n1698  NotPrice
# 26       $0-20M 0%\n$20-50M 1.5%\n$50-75M 2.5%\n$75M+ 3.5%  NotPrice
# 27       $5,626,000\n(4DCM)\n$4,607,500\n(3DCM)\n$3,550...  NotPrice
# 28                                                      35  NotPrice
# 29                                                      72  NotPrice
# ...                                                    ...       ...
# 9386756                                         $66,600.00  NotPrice
# 9386757                                 Field Service Type  NotPrice
# 9386758                                                 US  NotPrice
# 9386759                                              China  NotPrice
# 9386760                     FSE\nAnnual 40 hrs/wk (52 wks)  NotPrice
# 9386761                                             $3,000  NotPrice
# 9386762                                               $830  NotPrice
# 9386763                                       FSE - Hourly  NotPrice
# 9386764                                              $67.3  NotPrice
# 9386765                                                $20  NotPrice
# 9386766                           Applicable\nAddendum No.  NotPrice
# 9386767                           Product Line Description  NotPrice
# 9386768                      Consolidation Point Location.  NotPrice
# 9386769                                      3PL\nProvider  NotPrice
# 9386770              Intel Designated\nWarehouse\nLocation  NotPrice
# 9386771                                      A.l.A Table 1  NotPrice
# 9386772                                    Specialty Gases  NotPrice
# 9386773                         Research Triangle Park. NC  NotPrice
# 9386774                                              Linde  NotPrice
# 9386775                                     China (Bonded)  NotPrice
# 9386776                                      A.l.A Table 1  NotPrice
# 9386777                                    Specialty Gases  NotPrice
# 9386778                         Research Triangle Park. NC  NotPrice
# 9386779                                              Linde  NotPrice
# 9386780                                   Ireland (Bonded)  NotPrice
# 9386781                                      A.l.A Table 1  NotPrice
# 9386782                                    Specialty Gases  NotPrice
# 9386783                                       Savannah. GA  NotPrice
# 9386784                                            Rinchem  NotPrice
# 9386785                                             Israel  NotPrice
#
# [9386786 rows x 5 columns]

# %%
df_filtered = df_training[df_training['Label'] == 'Price']
df_grouped = df_filtered.groupby(['DocumentId','TableNumber','ColumnNumber'])['ColumnNumber'].count().reset_index(name="count")
df_grouped
# Out:
#        DocumentId  TableNumber  ColumnNumber  count
# 0   Doc1200362136           31             0      1
# 1   Doc1200903348           30             0      1
# 2   Doc1201585322           28             0      1
# 3   Doc1603072761            0             2      6
# 4   Doc1603072761            1             3      2
# 5   Doc1603072761            3             2      3
# 6   Doc1603072761            4             2      7
# 7   Doc1627650987            0             0      1
# 8   Doc2044033097            2             7      1
# 9   Doc2044033097            2             8     24
# 10  Doc2090637515           10             2      1
# 11  Doc2091386045           10             2      1
# 12  Doc2092943547           11             2      1

# %%
df_grouped = df_grouped.loc[df_grouped.groupby(["DocumentId", "TableNumber"])["count"].idxmax()]
df_grouped['DocNumTableNum'] = df_grouped['DocumentId'].apply(str) + '/' + df_grouped['TableNumber'].apply(str)
df_grouped['DocNumTableNumColumnNumber'] = df_grouped['DocumentId'].apply(str) + '/' + df_grouped['TableNumber'].apply(str) + '/' + df_grouped['ColumnNumber'].apply(str)
df_grouped
# Out:
#        DocumentId  TableNumber  ColumnNumber  count    DocNumTableNum  \
# 0   Doc1200362136           31             0      1  Doc1200362136/31
# 1   Doc1200903348           30             0      1  Doc1200903348/30
# 2   Doc1201585322           28             0      1  Doc1201585322/28
# 3   Doc1603072761            0             2      6   Doc1603072761/0
# 4   Doc1603072761            1             3      2   Doc1603072761/1
# 5   Doc1603072761            3             2      3   Doc1603072761/3
# 6   Doc1603072761            4             2      7   Doc1603072761/4
# 7   Doc1627650987            0             0      1   Doc1627650987/0
# 9   Doc2044033097            2             8     24   Doc2044033097/2
# 10  Doc2090637515           10             2      1  Doc2090637515/10
# 11  Doc2091386045           10             2      1  Doc2091386045/10
# 12  Doc2092943547           11             2      1  Doc2092943547/11
#
#    DocNumTableNumColumnNumber
# 0          Doc1200362136/31/0
# 1          Doc1200903348/30/0
# 2          Doc1201585322/28/0
# 3           Doc1603072761/0/2
# 4           Doc1603072761/1/3
# 5           Doc1603072761/3/2
# 6           Doc1603072761/4/2
# 7           Doc1627650987/0/0
# 9           Doc2044033097/2/8
# 10         Doc2090637515/10/2
# 11         Doc2091386045/10/2
# 12         Doc2092943547/11/2

# %%
df_t = df_training.groupby(['DocumentId','TableNumber','ColumnNumber']).ColumnValue.unique().reset_index()
df_t
# Out:
#            DocumentId  TableNumber  ColumnNumber  \
# 0       Doc1000015244            0             0
# 1       Doc1000015244            0             1
# 2       Doc1000015244            1             0
# 3       Doc1000015244            1             1
# 4       Doc1000015244            1             2
# 5       Doc1000015244            1             3
# 6       Doc1000015244            1             4
# 7       Doc1000015244            1             5
# 8       Doc1000015244            1             6
# 9       Doc1000015244            1             7
# 10      Doc1000015244            1             8
# 11      Doc1000015244            1             9
# 12      Doc1000015244            1            10
# 13      Doc1000015244            1            11
# 14      Doc1000015244            1            12
# 15      Doc1000015244            1            13
# 16      Doc1000015244            2             0
# 17      Doc1000015244            2             1
# 18      Doc1000015244            2             2
# 19      Doc1000015244            2             3
# 20      Doc1000015244            2             4
# 21      Doc1000015244            2             5
# 22      Doc1000015244            2             6
# 23      Doc1000015244            3             0
# 24      Doc1000015244            3             1
# 25      Doc1000015244            3             2
# 26      Doc1000015244            3             3
# 27      Doc1000015244            3             4
# 28      Doc1000015244            3             5
# 29      Doc1000015244            3             6
# ...               ...          ...           ...
# 727262   Doc999948248            9             1
# 727263   Doc999948248            9             2
# 727264   Doc999948248            9             3
# 727265   Doc999948248            9             4
# 727266   Doc999948248            9             5
# 727267   Doc999948248           10             0
# 727268   Doc999948248           10             1
# 727269   Doc999948248           10             2
# 727270   Doc999948248           11             0
# 727271   Doc999948248           11             1
# 727272   Doc999948248           12             0
# 727273   Doc999948248           12             1
# 727274   Doc999948248           12             2
# 727275   Doc999948248           12             3
# 727276   Doc999948248           13             0
# 727277   Doc999948248           13             1
# 727278   Doc999948248           13             2
# 727279   Doc999948248           13             3
# 727280   Doc999948248           14             0
# 727281   Doc999948248           14             1
# 727282   Doc999948248           14             2
# 727283   Doc999948248           14             3
# 727284   Doc999948248           15             0
# 727285   Doc999948248           15             1
# 727286   Doc999948248           15             2
# 727287   Doc999948248           15             3
# 727288   Doc999948248           16             0
# 727289   Doc999948248           16             1
# 727290   Doc999948248           16             2
# 727291   Doc999948248           16             3
#
#                                               ColumnValue
# 0                                    [BY:, NAME:, TITLE:]
# 1                                    [BY:, NAME:, TITLE:]
# 2                  [Equipment\nModel, Synergis MX, Notes]
# 3       [Material\nMaster\nNumber, TBD, - Ozone Genera...
# 4                    [Material\nMaster\nDescription, TBD]
# 5                                             [CEID, ABV]
# 6                                  [P-\nSpec, 06P-\n1944]
# 7                                  [C-\nSPEC, 06C-\n1698]
# 8       [Pricing\nStructureDis\ncount (capital\nspends...
# 9       [Contract\nPrice\n(currency\nsymbol), $5,626,0...
# 10      [Pre-fac Tender\nprior to\nEquiment STD\n(Days...
# 11                        [Forecast\nNotice in\nDays, 72]
# 12                   [Forecasted\nLead Time\nin Days, 98]
# 13      [Unforecasted\nLead Time in\nDays, 112\n(max 2...
# 14                                 [Expiration, 11/11/21]
# 15      [Comments, Configuration\nwith Al2O3\nCoating ...
# 16      [Equipment Model, 4 channel Ozone Generator Ra...
# 17                        [Material\nMaster\nNumber, TBD]
# 18                   [Material\nMaster\nDescription, TBD]
# 19      [Pricing\nStructure, 2x O3 Gen\n3x O3 Gen\n4x ...
# 20      [Contract Price, $414,500\n$472,833\n$531,622,...
# 21                   [Expiration, 11/11/2021, 11/21/2021]
# 22      [Comments, Ozone Generators would be ordered a...
# 23      [Equipment\nModel, Single\nGenerator\nUpgrade ...
# 24                        [Material\nMaster\nNumber, TBD]
# 25                    [Material Master\nDescription, TBD]
# 26                             [Pricing\nStructure, Each]
# 27                             [Contract\nPrice, $61,667]
# 28                        [Forecast\nNotice in\nDays, NA]
# 29                   [Forecasted\nLead Time in\nDays, 84]
# ...                                                   ...
# 727262  [Initial Response Goal, Definition, Severe pro...
# 727263  [Relief** Target, Basic\nSupport\nfor CM, 2 bu...
# 727264  [Enhanced\nSupport, 1 hour, 2 business\nhours*...
# 727265  [Designated\nSupport\nEngineer, Direct Connect...
# 727266  [(Attempt to\nprovide relief\nwithin...), 1 da...
# 727267  [Unit of Measure, Central Processing Unit, Cor...
# 727268  [Code, CPU, Core, GB, TB, PB, , HST, MAILBX(S)...
# 727269  [Description, The maximum number of CPUs upon ...
# 727270  [SOFTWARE, WEBTOP, PURE CUSTOM CLIENT, DOCUMEN...
# 727271                                        [UOM, SEAT]
# 727272  [Product, DOCUMENTUM PLATFORM, DOCUMENTUM PLAT...
# 727273  [Model Number, 457-100-351, 457-100-360, 457-1...
# 727274  [Unit of Measure, SEAT, ADAPTOR, 2-CORE CPU, P...
# 727275                      [Royalty Bearing, , yes, Yes]
# 727276  [INTERACTIVE DELIVERY SERVICES TARGET CORE, IN...
# 727277  [IDS-TAR-MC, IDSA-SRC-MC, IDSA-TAR-MC, , 457-1...
# 727278  [2-CORE CPU;\nMINIMUM\nPURCHASE OF 4\nCORES (1...
# 727279                                       [, yes, Yes]
# 727280  [xDoc Departmental to Enterprise Lite, xDoc St...
# 727281  [456-101-864, 456-101-862, 456-101-865, 457-10...
# 727282  [Up to Four 4-CPUs\nServers + 4\nWorkstations,...
# 727283                                            [, yes]
# 727284  [xPresso for Dreamweaver Client, xPresso for I...
# 727285  [456-101-530, 456-101-529, 456-101-526, , 456-...
# 727286  [Named User Client, , Per TB, Per Node, Per No...
# 727287                       [, Yes, Hardware Costs, yes]
# 727288  [German Language Pack, Spanish Language Pack, ...
# 727289  [456-101-188, 456-101-190, 456-101-189, 457-10...
# 727290  [Per Discovered\nCustodian, Per Reviewed\nCust...
# 727291                                            [, yes]
#
# [727292 rows x 4 columns]

# %%
df_t['DocNumTableNum'] = df_t['DocumentId'] + '/' + df_t['TableNumber'].apply(str)
df_t['DocNumTableNumColumnNumber'] = df_t['DocumentId'] + '/' + df_t['TableNumber'].apply(str) + '/' + df_t['ColumnNumber'].apply(str)
df_t['Label'] = np.where(df_t['DocNumTableNumColumnNumber'].isin(df_grouped.DocNumTableNumColumnNumber.tolist()), 'Price', 'Other')
df_t['PriceInTable'] = np.where(df_t['DocNumTableNum'].isin(df_grouped.DocNumTableNum.tolist()), 'Yes','No')
df_t['Label'] = df_t.apply(lambda row: 'NotPrice' if (row['Label']=='Other')&(row['PriceInTable'] == 'Yes' ) else row['Label'],axis=1)
#df_t[df_t['Label']=='Other']
#df_t[(df_t['Label']=='Other')&(df_t['test']=='NotPrice')]
df_t
# Out:
#            DocumentId  TableNumber  ColumnNumber  \
# 0       Doc1000015244            0             0
# 1       Doc1000015244            0             1
# 2       Doc1000015244            1             0
# 3       Doc1000015244            1             1
# 4       Doc1000015244            1             2
# 5       Doc1000015244            1             3
# 6       Doc1000015244            1             4
# 7       Doc1000015244            1             5
# 8       Doc1000015244            1             6
# 9       Doc1000015244            1             7
# 10      Doc1000015244            1             8
# 11      Doc1000015244            1             9
# 12      Doc1000015244            1            10
# 13      Doc1000015244            1            11
# 14      Doc1000015244            1            12
# 15      Doc1000015244            1            13
# 16      Doc1000015244            2             0
# 17      Doc1000015244            2             1
# 18      Doc1000015244            2             2
# 19      Doc1000015244            2             3
# 20      Doc1000015244            2             4
# 21      Doc1000015244            2             5
# 22      Doc1000015244            2             6
# 23      Doc1000015244            3             0
# 24      Doc1000015244            3             1
# 25      Doc1000015244            3             2
# 26      Doc1000015244            3             3
# 27      Doc1000015244            3             4
# 28      Doc1000015244            3             5
# 29      Doc1000015244            3             6
# ...               ...          ...           ...
# 727262   Doc999948248            9             1
# 727263   Doc999948248            9             2
# 727264   Doc999948248            9             3
# 727265   Doc999948248            9             4
# 727266   Doc999948248            9             5
# 727267   Doc999948248           10             0
# 727268   Doc999948248           10             1
# 727269   Doc999948248           10             2
# 727270   Doc999948248           11             0
# 727271   Doc999948248           11             1
# 727272   Doc999948248           12             0
# 727273   Doc999948248           12             1
# 727274   Doc999948248           12             2
# 727275   Doc999948248           12             3
# 727276   Doc999948248           13             0
# 727277   Doc999948248           13             1
# 727278   Doc999948248           13             2
# 727279   Doc999948248           13             3
# 727280   Doc999948248           14             0
# 727281   Doc999948248           14             1
# 727282   Doc999948248           14             2
# 727283   Doc999948248           14             3
# 727284   Doc999948248           15             0
# 727285   Doc999948248           15             1
# 727286   Doc999948248           15             2
# 727287   Doc999948248           15             3
# 727288   Doc999948248           16             0
# 727289   Doc999948248           16             1
# 727290   Doc999948248           16             2
# 727291   Doc999948248           16             3
#
#                                               ColumnValue   DocNumTableNum  \
# 0                                    [BY:, NAME:, TITLE:]  Doc1000015244/0
# 1                                    [BY:, NAME:, TITLE:]  Doc1000015244/0
# 2                  [Equipment\nModel, Synergis MX, Notes]  Doc1000015244/1
# 3       [Material\nMaster\nNumber, TBD, - Ozone Genera...  Doc1000015244/1
# 4                    [Material\nMaster\nDescription, TBD]  Doc1000015244/1
# 5                                             [CEID, ABV]  Doc1000015244/1
# 6                                  [P-\nSpec, 06P-\n1944]  Doc1000015244/1
# 7                                  [C-\nSPEC, 06C-\n1698]  Doc1000015244/1
# 8       [Pricing\nStructureDis\ncount (capital\nspends...  Doc1000015244/1
# 9       [Contract\nPrice\n(currency\nsymbol), $5,626,0...  Doc1000015244/1
# 10      [Pre-fac Tender\nprior to\nEquiment STD\n(Days...  Doc1000015244/1
# 11                        [Forecast\nNotice in\nDays, 72]  Doc1000015244/1
# 12                   [Forecasted\nLead Time\nin Days, 98]  Doc1000015244/1
# 13      [Unforecasted\nLead Time in\nDays, 112\n(max 2...  Doc1000015244/1
# 14                                 [Expiration, 11/11/21]  Doc1000015244/1
# 15      [Comments, Configuration\nwith Al2O3\nCoating ...  Doc1000015244/1
# 16      [Equipment Model, 4 channel Ozone Generator Ra...  Doc1000015244/2
# 17                        [Material\nMaster\nNumber, TBD]  Doc1000015244/2
# 18                   [Material\nMaster\nDescription, TBD]  Doc1000015244/2
# 19      [Pricing\nStructure, 2x O3 Gen\n3x O3 Gen\n4x ...  Doc1000015244/2
# 20      [Contract Price, $414,500\n$472,833\n$531,622,...  Doc1000015244/2
# 21                   [Expiration, 11/11/2021, 11/21/2021]  Doc1000015244/2
# 22      [Comments, Ozone Generators would be ordered a...  Doc1000015244/2
# 23      [Equipment\nModel, Single\nGenerator\nUpgrade ...  Doc1000015244/3
# 24                        [Material\nMaster\nNumber, TBD]  Doc1000015244/3
# 25                    [Material Master\nDescription, TBD]  Doc1000015244/3
# 26                             [Pricing\nStructure, Each]  Doc1000015244/3
# 27                             [Contract\nPrice, $61,667]  Doc1000015244/3
# 28                        [Forecast\nNotice in\nDays, NA]  Doc1000015244/3
# 29                   [Forecasted\nLead Time in\nDays, 84]  Doc1000015244/3
# ...                                                   ...              ...
# 727262  [Initial Response Goal, Definition, Severe pro...   Doc999948248/9
# 727263  [Relief** Target, Basic\nSupport\nfor CM, 2 bu...   Doc999948248/9
# 727264  [Enhanced\nSupport, 1 hour, 2 business\nhours*...   Doc999948248/9
# 727265  [Designated\nSupport\nEngineer, Direct Connect...   Doc999948248/9
# 727266  [(Attempt to\nprovide relief\nwithin...), 1 da...   Doc999948248/9
# 727267  [Unit of Measure, Central Processing Unit, Cor...  Doc999948248/10
# 727268  [Code, CPU, Core, GB, TB, PB, , HST, MAILBX(S)...  Doc999948248/10
# 727269  [Description, The maximum number of CPUs upon ...  Doc999948248/10
# 727270  [SOFTWARE, WEBTOP, PURE CUSTOM CLIENT, DOCUMEN...  Doc999948248/11
# 727271                                        [UOM, SEAT]  Doc999948248/11
# 727272  [Product, DOCUMENTUM PLATFORM, DOCUMENTUM PLAT...  Doc999948248/12
# 727273  [Model Number, 457-100-351, 457-100-360, 457-1...  Doc999948248/12
# 727274  [Unit of Measure, SEAT, ADAPTOR, 2-CORE CPU, P...  Doc999948248/12
# 727275                      [Royalty Bearing, , yes, Yes]  Doc999948248/12
# 727276  [INTERACTIVE DELIVERY SERVICES TARGET CORE, IN...  Doc999948248/13
# 727277  [IDS-TAR-MC, IDSA-SRC-MC, IDSA-TAR-MC, , 457-1...  Doc999948248/13
# 727278  [2-CORE CPU;\nMINIMUM\nPURCHASE OF 4\nCORES (1...  Doc999948248/13
# 727279                                       [, yes, Yes]  Doc999948248/13
# 727280  [xDoc Departmental to Enterprise Lite, xDoc St...  Doc999948248/14
# 727281  [456-101-864, 456-101-862, 456-101-865, 457-10...  Doc999948248/14
# 727282  [Up to Four 4-CPUs\nServers + 4\nWorkstations,...  Doc999948248/14
# 727283                                            [, yes]  Doc999948248/14
# 727284  [xPresso for Dreamweaver Client, xPresso for I...  Doc999948248/15
# 727285  [456-101-530, 456-101-529, 456-101-526, , 456-...  Doc999948248/15
# 727286  [Named User Client, , Per TB, Per Node, Per No...  Doc999948248/15
# 727287                       [, Yes, Hardware Costs, yes]  Doc999948248/15
# 727288  [German Language Pack, Spanish Language Pack, ...  Doc999948248/16
# 727289  [456-101-188, 456-101-190, 456-101-189, 457-10...  Doc999948248/16
# 727290  [Per Discovered\nCustodian, Per Reviewed\nCust...  Doc999948248/16
# 727291                                            [, yes]  Doc999948248/16
#
#        DocNumTableNumColumnNumber  Label PriceInTable
# 0               Doc1000015244/0/0  Other           No
# 1               Doc1000015244/0/1  Other           No
# 2               Doc1000015244/1/0  Other           No
# 3               Doc1000015244/1/1  Other           No
# 4               Doc1000015244/1/2  Other           No
# 5               Doc1000015244/1/3  Other           No
# 6               Doc1000015244/1/4  Other           No
# 7               Doc1000015244/1/5  Other           No
# 8               Doc1000015244/1/6  Other           No
# 9               Doc1000015244/1/7  Other           No
# 10              Doc1000015244/1/8  Other           No
# 11              Doc1000015244/1/9  Other           No
# 12             Doc1000015244/1/10  Other           No
# 13             Doc1000015244/1/11  Other           No
# 14             Doc1000015244/1/12  Other           No
# 15             Doc1000015244/1/13  Other           No
# 16              Doc1000015244/2/0  Other           No
# 17              Doc1000015244/2/1  Other           No
# 18              Doc1000015244/2/2  Other           No
# 19              Doc1000015244/2/3  Other           No
# 20              Doc1000015244/2/4  Other           No
# 21              Doc1000015244/2/5  Other           No
# 22              Doc1000015244/2/6  Other           No
# 23              Doc1000015244/3/0  Other           No
# 24              Doc1000015244/3/1  Other           No
# 25              Doc1000015244/3/2  Other           No
# 26              Doc1000015244/3/3  Other           No
# 27              Doc1000015244/3/4  Other           No
# 28              Doc1000015244/3/5  Other           No
# 29              Doc1000015244/3/6  Other           No
# ...                           ...    ...          ...
# 727262           Doc999948248/9/1  Other           No
# 727263           Doc999948248/9/2  Other           No
# 727264           Doc999948248/9/3  Other           No
# 727265           Doc999948248/9/4  Other           No
# 727266           Doc999948248/9/5  Other           No
# 727267          Doc999948248/10/0  Other           No
# 727268          Doc999948248/10/1  Other           No
# 727269          Doc999948248/10/2  Other           No
# 727270          Doc999948248/11/0  Other           No
# 727271          Doc999948248/11/1  Other           No
# 727272          Doc999948248/12/0  Other           No
# 727273          Doc999948248/12/1  Other           No
# 727274          Doc999948248/12/2  Other           No
# 727275          Doc999948248/12/3  Other           No
# 727276          Doc999948248/13/0  Other           No
# 727277          Doc999948248/13/1  Other           No
# 727278          Doc999948248/13/2  Other           No
# 727279          Doc999948248/13/3  Other           No
# 727280          Doc999948248/14/0  Other           No
# 727281          Doc999948248/14/1  Other           No
# 727282          Doc999948248/14/2  Other           No
# 727283          Doc999948248/14/3  Other           No
# 727284          Doc999948248/15/0  Other           No
# 727285          Doc999948248/15/1  Other           No
# 727286          Doc999948248/15/2  Other           No
# 727287          Doc999948248/15/3  Other           No
# 727288          Doc999948248/16/0  Other           No
# 727289          Doc999948248/16/1  Other           No
# 727290          Doc999948248/16/2  Other           No
# 727291          Doc999948248/16/3  Other           No
#
# [727292 rows x 8 columns]

# %%
import re
import nltk
#nltk.download('stopwords')

def listToString(s):  
    str1 = " "  
    return str1.join(s)

def remove_numbers(wordtoken):
    return re.sub(r'\d',r'_',wordtoken)

def tokenize_string(strng):
    #if not strng:
    #    print('The text to be tokenized is a None type. Defaulting to blank string.')
    #    strng = ''
    return nltk.word_tokenize(strng)

punct= list('"\'()*`{|}~/')
def remove_punct(wordtokens):
    return [wordtoken for wordtoken in wordtokens if wordtoken not in punct]

df_t['Col_Tokens'] = df_t.ColumnValue.apply(listToString)
df_t['Col_Tokens'] = df_t.Col_Tokens.apply(remove_numbers)
df_t['Col_Tokens'] = df_t.Col_Tokens.apply(tokenize_string)

# %%
stopwords= set(nltk.corpus.stopwords.words('english'))
def remove_stopwords(wordtokens):
    return [wordtoken for wordtoken in wordtokens if wordtoken not in stopwords]

# Porter Stem Tokens
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem_tokens(wordtokens):
    return [ps.stem(word) for word in wordtokens]

df_t['Col_Tokens'] = df_t.Col_Tokens.apply(remove_stopwords)
df_t['Col_Tokens'] = df_t.Col_Tokens.apply(remove_punct)
df_t['Col_Tokens'] = df_t.Col_Tokens.apply(stem_tokens)

# %%
df_tr = df_t[(df_t['Label']=='Price') | (df_t['Label']=='NotPrice')]
df_tr[(df_tr['Label']=='Price')]
# Out:
#            DocumentId  TableNumber  ColumnNumber  \
# 111461  Doc1200362136           31             0
# 112048  Doc1200903348           30             0
# 112638  Doc1201585322           28             0
# 256462  Doc1603072761            0             2
# 256470  Doc1603072761            1             3
# 256478  Doc1603072761            3             2
# 256481  Doc1603072761            4             2
# 259810  Doc1627650987            0             0
# 362924  Doc2044033097            2             8
# 376564  Doc2090637515           10             2
# 376814  Doc2091386045           10             2
# 377113  Doc2092943547           11             2
#
#                                               ColumnValue    DocNumTableNum  \
# 111461  [https-browserify, iconv-lite, immediate, inde...  Doc1200362136/31
# 112048  [http- parse r-js, https-browserify, iconv-lit...  Doc1200903348/30
# 112638  [http- parse r-js, https-browserify, iconv-lit...  Doc1201585322/28
# 256462  [, an* aio, ni'an, m>an, m*an, nimpn minx\nno ...   Doc1603072761/0
# 256470  [, m*n Jim', I'D, nan, 20 tip - 'n*\n"7, 60 tj...   Doc1603072761/1
# 256478  [aionrnN, man, nan, mmpo niTHN\nno wo/, pina Q...   Doc1603072761/3
# 256481  [200 - p'uobg nmn\nneb, nmip -looono'b, D'pDpD...   Doc1603072761/4
# 259810  [nVan\nn wiAt-;\njvwrin\nDyw ■'\nnViso\n•' 's'...   Doc1627650987/0
# 362924  [New $/KG, $1,235, 11.39, 3,465.00, 1,255.50, ...   Doc2044033097/2
# 376564  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2090637515/10
# 376814  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2091386045/10
# 377113  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2092943547/11
#
#        DocNumTableNumColumnNumber  Label PriceInTable  \
# 111461         Doc1200362136/31/0  Price          Yes
# 112048         Doc1200903348/30/0  Price          Yes
# 112638         Doc1201585322/28/0  Price          Yes
# 256462          Doc1603072761/0/2  Price          Yes
# 256470          Doc1603072761/1/3  Price          Yes
# 256478          Doc1603072761/3/2  Price          Yes
# 256481          Doc1603072761/4/2  Price          Yes
# 259810          Doc1627650987/0/0  Price          Yes
# 362924          Doc2044033097/2/8  Price          Yes
# 376564         Doc2090637515/10/2  Price          Yes
# 376814         Doc2091386045/10/2  Price          Yes
# 377113         Doc2092943547/11/2  Price          Yes
#
#                                                Col_Tokens
# 111461  [https-browserifi, iconv-lit, immedi, indexof,...
# 112048  [http-, pars, r-j, https-browserifi, iconv-lit...
# 112638  [http-, pars, r-j, https-browserifi, iconv-lit...
# 256462  [an*, aio, ni'an, >, m*an, nimpn, minx, \unl, ...
# 256470  [m*n, jim, I, 'D, nan, __, tip, -, n*, '', _, ...
# 256478  [aionrnn, man, nan, mmpo, nithn, wo/, pina, q'...
# 256481  [___, -, p'uobg, nmn, neb, nmip, -looono, b, d...
# 259810  [nvan, n, wiat-, ;, jvwrin, dyw, ■', nviso, •,...
# 362924  [new, $, /kg, $, _, ,, ___, __.__, _, ,, ___._...
# 376564  [____-____, price, $, _, ,, ___, $, _, ,, ___,...
# 376814  [____-____, price, $, _, ,, ___, $, _, ,, ___,...
# 377113  [____-____, price, $, _, ,, ___, $, _, ,, ___,...

# %%
df_tr_final = df_t[df_t['DocNumTableNum'].isin(df_tr.DocNumTableNum.tolist())]
df_tr_final
# Out:
#            DocumentId  TableNumber  ColumnNumber  \
# 111461  Doc1200362136           31             0
# 111462  Doc1200362136           31             1
# 111463  Doc1200362136           31             2
# 111464  Doc1200362136           31             3
# 112048  Doc1200903348           30             0
# 112049  Doc1200903348           30             1
# 112050  Doc1200903348           30             2
# 112051  Doc1200903348           30             3
# 112638  Doc1201585322           28             0
# 112639  Doc1201585322           28             1
# 112640  Doc1201585322           28             2
# 112641  Doc1201585322           28             3
# 256460  Doc1603072761            0             0
# 256461  Doc1603072761            0             1
# 256462  Doc1603072761            0             2
# 256463  Doc1603072761            0             3
# 256464  Doc1603072761            0             4
# 256465  Doc1603072761            0             5
# 256466  Doc1603072761            0             6
# 256467  Doc1603072761            1             0
# 256468  Doc1603072761            1             1
# 256469  Doc1603072761            1             2
# 256470  Doc1603072761            1             3
# 256471  Doc1603072761            1             4
# 256472  Doc1603072761            1             5
# 256473  Doc1603072761            1             6
# 256476  Doc1603072761            3             0
# 256477  Doc1603072761            3             1
# 256478  Doc1603072761            3             2
# 256479  Doc1603072761            4             0
# ...               ...          ...           ...
# 362924  Doc2044033097            2             8
# 362925  Doc2044033097            2             9
# 362926  Doc2044033097            2            10
# 362927  Doc2044033097            2            11
# 362928  Doc2044033097            2            12
# 362929  Doc2044033097            2            13
# 376562  Doc2090637515           10             0
# 376563  Doc2090637515           10             1
# 376564  Doc2090637515           10             2
# 376565  Doc2090637515           10             3
# 376566  Doc2090637515           10             4
# 376567  Doc2090637515           10             5
# 376568  Doc2090637515           10             6
# 376569  Doc2090637515           10             7
# 376812  Doc2091386045           10             0
# 376813  Doc2091386045           10             1
# 376814  Doc2091386045           10             2
# 376815  Doc2091386045           10             3
# 376816  Doc2091386045           10             4
# 376817  Doc2091386045           10             5
# 376818  Doc2091386045           10             6
# 376819  Doc2091386045           10             7
# 377111  Doc2092943547           11             0
# 377112  Doc2092943547           11             1
# 377113  Doc2092943547           11             2
# 377114  Doc2092943547           11             3
# 377115  Doc2092943547           11             4
# 377116  Doc2092943547           11             5
# 377117  Doc2092943547           11             6
# 377118  Doc2092943547           11             7
#
#                                               ColumnValue    DocNumTableNum  \
# 111461  [https-browserify, iconv-lite, immediate, inde...  Doc1200362136/31
# 111462  [1.0.0, 0.4.19, 3.0.6, 0.0.1, 0.6.2, 7.0.1, 1....  Doc1200362136/31
# 111463  [MIT, (MIT OR Apache-2.0), (MIT OR GPL-3.0), (...  Doc1200362136/31
# 111464  [https://github.com/substack/https-browserify/...  Doc1200362136/31
# 112048  [http- parse r-js, https-browserify, iconv-lit...  Doc1200903348/30
# 112049  [0.4.9, 1.0.0, 0.4.19, 3.0.6, 0.0.1, 0.6.2, 7....  Doc1200903348/30
# 112050  [MIT, (MIT OR Apache-2.0), (MIT OR GPL-3.0), (...  Doc1200903348/30
# 112051  [https://github.com/creationix/http-parser-is/...  Doc1200903348/30
# 112638  [http- parse r-js, https-browserify, iconv-lit...  Doc1201585322/28
# 112639  [0.4.9, 1.0.0, 0.4.19, 3.0.6, 0.0.1, 0.6.2, 7....  Doc1201585322/28
# 112640  [MIT, (MIT OR Apache-2.0), (MIT OR GPL-3.0), (...  Doc1201585322/28
# 112641  [https://github.com/creationix/http-parser-is/...  Doc1201585322/28
# 256460  [, ■minn dw, mana di'jv*7 m*7*7io, (ni'm*7 x'x...   Doc1603072761/0
# 256461  [, nninn iikti, DI'JV1? 131*7*710, -Alkaline, ...   Doc1603072761/0
# 256462  [, an* aio, ni'an, m>an, m*an, nimpn minx\nno ...   Doc1603072761/0
# 256463  [, nTM rnn*, Kg, ton, kg, |I0, novyn, ni'an, n...   Doc1603072761/0
# 256464  [AL£, Huoniio, nmn, Tima, n-3T3xn3iyn, iKraxnx...   Doc1603072761/0
# 256465  [rf73im ‘719'OTnn, l"n / El 25, |IO/RU 2500, l...   Doc1603072761/0
# 256466  [RDF raw TOT no, , nan/©118, nan/® 118, n*an/©...   Doc1603072761/0
# 256467  [, "imnn ow, (|IO) 'lAIIX V(ll *719*0, 'UIPNIN...   Doc1603072761/1
# 256468  [, ininn mx'ii, IP D**7TI3 J1 I'lXTil I3OT') O...   Doc1603072761/1
# 256469                                       [, ilHK 110]   Doc1603072761/1
# 256470  [, m*n Jim', I'D, nan, 20 tip - 'n*\n"7, 60 tj...   Doc1603072761/1
# 256471  [AUE, I\na\na, , n*i*QN nawn, *7110*3, mmn, ru...   Doc1603072761/1
# 256472  [n*?iini tool* nn, 11**70 ino *?i) |m* i*nn\ni...   Doc1603072761/1
# 256473                  [RDF ram nuiTnn, , n*in/ it) 118]   Doc1603072761/1
# 256476  [Dunmnn, mano Di'n'b mbbio, manu noiw mbbio\n□...   Doc1603072761/3
# 256477  [minn tint, non mbbio: Alkaline, Nickel-Cadmiu...   Doc1603072761/3
# 256478  [aionrnN, man, nan, mmpo niTHN\nno wo/, pina Q...   Doc1603072761/3
# 256479  [Dnmn mpn nunN\n□ '3DIOO, Dnmn mpn nunN\nDDDIO...   Doc1603072761/4
# ...                                                   ...               ...
# 362924  [New $/KG, $1,235, 11.39, 3,465.00, 1,255.50, ...   Doc2044033097/2
# 362925                   [Site, AZ, OR,\nand IS, $, 3.95]   Doc2044033097/2
# 362926  [Shipping Term, DDP (for OR and AZ),\nDAP for ...   Doc2044033097/2
# 362927    [Notes, New\nMaterial, DL, NM, NM, OR, IR, DAP]   Doc2044033097/2
# 362928               [DAP, DDP, DDP, except for IR=EXW, ]   Doc2044033097/2
# 362929                                                 []   Doc2044033097/2
# 376562  [Hardware:, Item #, 102511-xxxx, 102513-xxxx, ...  Doc2090637515/10
# 376563  [Item description, Airnet II 201-4 (4ch), Airn...  Doc2090637515/10
# 376564  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2090637515/10
# 376565  [Contract Lead¬\nTime, ARO, small\nquantities,...  Doc2090637515/10
# 376566  [Typical Lead¬\nTime, ARO, small\nquantities, ...  Doc2090637515/10
# 376567          [Parts\nWarranty, 36, 24, 12, 36 *, 12**]  Doc2090637515/10
# 376568                            [Service\nWarranty, 12]  Doc2090637515/10
# 376569  [Adder for 36\nmonth (total)\nparts warranty, ...  Doc2090637515/10
# 376812  [Hardware:, Item #, 102511-xxxx, 102513-xxxx, ...  Doc2091386045/10
# 376813  [Item description, Airnet II 201-4 (4ch), Airn...  Doc2091386045/10
# 376814  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2091386045/10
# 376815  [Contract Lead-\nTime, ARO, small\nquantities,...  Doc2091386045/10
# 376816  [Typical Lead-\nTime, ARO, small\nquantities, ...  Doc2091386045/10
# 376817           [Parts\nWarranty, 36, 24, 12, 36*, 12**]  Doc2091386045/10
# 376818                            [Service\nWarranty, 12]  Doc2091386045/10
# 376819  [Adderfor 36\nmonth (total)\nparts warranty, N...  Doc2091386045/10
# 377111  [Hardware:, Item #, 102511-xxxx, 102513-xxxx, ...  Doc2092943547/11
# 377112  [Item description, Airnet II 201-4 (4ch), Airn...  Doc2092943547/11
# 377113  [2019-2020 Price, $ 1,596, $ 1,674, $ 1,500, $...  Doc2092943547/11
# 377114  [Contract Lead-\nTime, ARO, small\nquantities,...  Doc2092943547/11
# 377115  [Typical Lead-\nTime, ARO, small\nquantities, ...  Doc2092943547/11
# 377116           [Parts\nWarranty, 36, 24, 12, 36*, 12**]  Doc2092943547/11
# 377117                            [Service\nWarranty, 12]  Doc2092943547/11
# 377118  [Adderfor 36\nmonth (total)\nparts warranty, N...  Doc2092943547/11
#
#        DocNumTableNumColumnNumber     Label PriceInTable  \
# 111461         Doc1200362136/31/0     Price          Yes
# 111462         Doc1200362136/31/1  NotPrice          Yes
# 111463         Doc1200362136/31/2  NotPrice          Yes
# 111464         Doc1200362136/31/3  NotPrice          Yes
# 112048         Doc1200903348/30/0     Price          Yes
# 112049         Doc1200903348/30/1  NotPrice          Yes
# 112050         Doc1200903348/30/2  NotPrice          Yes
# 112051         Doc1200903348/30/3  NotPrice          Yes
# 112638         Doc1201585322/28/0     Price          Yes
# 112639         Doc1201585322/28/1  NotPrice          Yes
# 112640         Doc1201585322/28/2  NotPrice          Yes
# 112641         Doc1201585322/28/3  NotPrice          Yes
# 256460          Doc1603072761/0/0  NotPrice          Yes
# 256461          Doc1603072761/0/1  NotPrice          Yes
# 256462          Doc1603072761/0/2     Price          Yes
# 256463          Doc1603072761/0/3  NotPrice          Yes
# 256464          Doc1603072761/0/4  NotPrice          Yes
# 256465          Doc1603072761/0/5  NotPrice          Yes
# 256466          Doc1603072761/0/6  NotPrice          Yes
# 256467          Doc1603072761/1/0  NotPrice          Yes
# 256468          Doc1603072761/1/1  NotPrice          Yes
# 256469          Doc1603072761/1/2  NotPrice          Yes
# 256470          Doc1603072761/1/3     Price          Yes
# 256471          Doc1603072761/1/4  NotPrice          Yes
# 256472          Doc1603072761/1/5  NotPrice          Yes
# 256473          Doc1603072761/1/6  NotPrice          Yes
# 256476          Doc1603072761/3/0  NotPrice          Yes
# 256477          Doc1603072761/3/1  NotPrice          Yes
# 256478          Doc1603072761/3/2     Price          Yes
# 256479          Doc1603072761/4/0  NotPrice          Yes
# ...                           ...       ...          ...
# 362924          Doc2044033097/2/8     Price          Yes
# 362925          Doc2044033097/2/9  NotPrice          Yes
# 362926         Doc2044033097/2/10  NotPrice          Yes
# 362927         Doc2044033097/2/11  NotPrice          Yes
# 362928         Doc2044033097/2/12  NotPrice          Yes
# 362929         Doc2044033097/2/13  NotPrice          Yes
# 376562         Doc2090637515/10/0  NotPrice          Yes
# 376563         Doc2090637515/10/1  NotPrice          Yes
# 376564         Doc2090637515/10/2     Price          Yes
# 376565         Doc2090637515/10/3  NotPrice          Yes
# 376566         Doc2090637515/10/4  NotPrice          Yes
# 376567         Doc2090637515/10/5  NotPrice          Yes
# 376568         Doc2090637515/10/6  NotPrice          Yes
# 376569         Doc2090637515/10/7  NotPrice          Yes
# 376812         Doc2091386045/10/0  NotPrice          Yes
# 376813         Doc2091386045/10/1  NotPrice          Yes
# 376814         Doc2091386045/10/2     Price          Yes
# 376815         Doc2091386045/10/3  NotPrice          Yes
# 376816         Doc2091386045/10/4  NotPrice          Yes
# 376817         Doc2091386045/10/5  NotPrice          Yes
# 376818         Doc2091386045/10/6  NotPrice          Yes
# 376819         Doc2091386045/10/7  NotPrice          Yes
# 377111         Doc2092943547/11/0  NotPrice          Yes
# 377112         Doc2092943547/11/1  NotPrice          Yes
# 377113         Doc2092943547/11/2     Price          Yes
# 377114         Doc2092943547/11/3  NotPrice          Yes
# 377115         Doc2092943547/11/4  NotPrice          Yes
# 377116         Doc2092943547/11/5  NotPrice          Yes
# 377117         Doc2092943547/11/6  NotPrice          Yes
# 377118         Doc2092943547/11/7  NotPrice          Yes
#
#                                                Col_Tokens
# 111461  [https-browserifi, iconv-lit, immedi, indexof,...
# 111462  [_._._, _._.__, _._._, _._._, _._._, _._._, _....
# 111463  [mit, mit, OR, apache-_._, mit, OR, gpl-_._, m...
# 111464  [http, :, //github.com/substack/https-browseri...
# 112048  [http-, pars, r-j, https-browserifi, iconv-lit...
# 112049  [_._._, _._._, _._.__, _._._, _._._, _._._, _....
# 112050  [mit, mit, OR, apache-_._, mit, OR, gpl-_._, m...
# 112051  [http, :, //github.com/creationix/http-parser-...
# 112638  [http-, pars, r-j, https-browserifi, iconv-lit...
# 112639  [_._._, _._._, _._.__, _._._, _._._, _._._, _....
# 112640  [mit, mit, OR, apache-_._, mit, OR, gpl-_._, m...
# 112641  [http, :, //github.com/creationix/http-parser-...
# 256460  [■minn, dw, mana, di'jv*_, m*_*_io, ni'm*_, x'...
# 256461  [nninn, iikti, di'jv_, ?, ___*_*___, -alkalin,...
# 256462  [an*, aio, ni'an, >, m*an, nimpn, minx, \unl, ...
# 256463  [ntm, rnn*, Kg, ton, kg, |i_, novyn, ni'an, nr...
# 256464  [al£, huoniio, nmn, tima, n-_t_xn_iyn, ikraxnx...
# 256465  [rf__im, ‘, ___'otnn, l, '', n, El, __, |io/ru...
# 256466  [rdf, raw, tot, nan/©___, nan/®, ___, n*an/©h_...
# 256467  [``, imnn, ow, |io, 'laiix, V, *___*_, 'uipnin...
# 256468  [ininn, mx'ii, IP, d**_ti_, J_, i'lxtil, i_ot,...
# 256469                                        [ilhk, ___]
# 256470  [m*n, jim, I, 'D, nan, __, tip, -, n*, '', _, ...
# 256471  [aue, I, n*i*qn, nawn, *____*_, mmn, run, nd'm...
# 256472  [n*, ?, iini, tool*, nn, __**__, ino, ?, |m*, ...
# 256473                     [rdf, ram, nuitnn, n*in/, ___]
# 256476  [dunmnn, mano, Di, n, b, mbbio, manu, noiw, mb...
# 256477  [minn, tint, non, mbbio, :, alkalin, ,, nickel...
# 256478  [aionrnn, man, nan, mmpo, nithn, wo/, pina, q'...
# 256479  [dnmn, mpn, nunn, □, '_dioo, dnmn, mpn, nunn, ...
# ...                                                   ...
# 362924  [new, $, /kg, $, _, ,, ___, __.__, _, ,, ___._...
# 362925                  [site, AZ, ,, OR, ,, IS, $, _.__]
# 362926  [ship, term, ddp, OR, AZ, ,, dap, IS, _.__, _....
# 362927  [note, new, materi, DL, NM, NM, ,, OR, ,, IR, ...
# 362928                 [dap, ddp, ddp, ,, except, ir=exw]
# 362929                                                 []
# 376562  [hardwar, :, item, #, ______-xxxx, ______-xxxx...
# 376563  [item, descript, airnet, II, ___-_, _ch, airne...
# 376564  [____-____, price, $, _, ,, ___, $, _, ,, ___,...
# 376565  [contract, lead¬, time, ,, aro, ,, small, quan...
# 376566  [typic, lead¬, time, ,, aro, ,, small, quantit...
# 376567             [part, warranti, __, __, __, __, __**]
# 376568                             [servic, warranti, __]
# 376569  [adder, __, month, total, part, warranti, n/a,...
# 376812  [hardwar, :, item, #, ______-xxxx, ______-xxxx...
# 376813  [item, descript, airnet, II, ___-_, _ch, airne...
# 376814  [____-____, price, $, _, ,, ___, $, _, ,, ___,...
# 376815  [contract, lead-, time, ,, aro, ,, small, quan...
# 376816  [typic, lead-, time, ,, aro, ,, small, quantit...
# 376817            [part, warranti, __, __, __, __*, __**]
# 376818                             [servic, warranti, __]
# 376819  [adderfor, __, month, total, part, warranti, n...
# 377111  [hardwar, :, item, #, ______-xxxx, ______-xxxx...
# 377112  [item, descript, airnet, II, ___-_, _ch, airne...
# 377113  [____-____, price, $, _, ,, ___, $, _, ,, ___,...
# 377114  [contract, lead-, time, ,, aro, ,, small, quan...
# 377115  [typic, lead-, time, ,, aro, ,, small, quantit...
# 377116            [part, warranti, __, __, __, __*, __**]
# 377117                             [servic, warranti, __]
# 377118  [adderfor, __, month, total, part, warranti, n...
#
# [79 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_tr_final.loc[:, 'Col_Tokens'], df_tr_final.loc[:, 'Label'], test_size=0.3, random_state=1)

# %%
def dummy_analyzer(x):
    return x

from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
rf_pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=dummy_analyzer)),
    ('RandomForestClassifier', RandomForestClassifier(n_estimators=100))
])

rf_pipeline.fit(X_train, y_train)
rf_predictions= rf_pipeline.predict(X_test)

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(classification_report(y_test, rf_predictions))
print(confusion_matrix(y_test, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#     NotPrice       0.96      1.00      0.98        22
#        Price       1.00      0.50      0.67         2
#
#    micro avg       0.96      0.96      0.96        24
#    macro avg       0.98      0.75      0.82        24
# weighted avg       0.96      0.96      0.95        24
#
# [[22  0]
#  [ 1  1]]

# %%
from sklearn.ensemble import ExtraTreesClassifier
xtra_pipeline= Pipeline([
    ('bow', CountVectorizer(analyzer=dummy_analyzer)),
    ('ExtraTreesClassifier', ExtraTreesClassifier(n_estimators=200))   
])

xtra_pipeline.fit(X_train, y_train)
xtra_predictions= xtra_pipeline.predict(X_test)

print(classification_report(y_test, xtra_predictions))
print(confusion_matrix(y_test, xtra_predictions))
# Out:
#               precision    recall  f1-score   support
#
#     NotPrice       0.96      1.00      0.98        65
#        Price       1.00      0.73      0.84        11
#
#    micro avg       0.96      0.96      0.96        76
#    macro avg       0.98      0.86      0.91        76
# weighted avg       0.96      0.96      0.96        76
#
# [[65  0]
#  [ 3  8]]

# %%
df_training[df_training['Label']=='Price']
# Out:
#             DocumentId  TableNumber  ColumnNumber ColumnValue  Label
# 1593976  Doc1200362136           31             0         nan  Price
# 1606437  Doc1200903348           30             0         nan  Price
# 1612577  Doc1201585322           28             0         nan  Price
# 3204847  Doc1603072761            0             2         nan  Price
# 3204875  Doc1603072761            0             2         nan  Price
# 3204882  Doc1603072761            0             2         nan  Price
# 3204889  Doc1603072761            0             2         nan  Price
# 3204896  Doc1603072761            0             2         nan  Price
# 3204903  Doc1603072761            0             2         nan  Price
# 3204937  Doc1603072761            1             3         nan  Price
# 3204972  Doc1603072761            1             3         nan  Price
# 3205084  Doc1603072761            3             2         nan  Price
# 3205087  Doc1603072761            3             2         nan  Price
# 3205090  Doc1603072761            3             2         nan  Price
# 3205156  Doc1603072761            4             2         nan  Price
# 3205159  Doc1603072761            4             2         nan  Price
# 3205171  Doc1603072761            4             2         nan  Price
# 3205174  Doc1603072761            4             2         nan  Price
# 3205180  Doc1603072761            4             2         nan  Price
# 3205183  Doc1603072761            4             2         nan  Price
# 3205186  Doc1603072761            4             2         nan  Price
# 3248787  Doc1627650987            0             0         nan  Price
# 4318849  Doc2004055208            0             5    4,023.39  Price
# 4318868  Doc2004055208            0             5    3,035.35  Price
# 4318886  Doc2004055208            0             5    3,035.35  Price
# 4318904  Doc2004055208            0             5    4,006.95  Price
# 4318920  Doc2004055208            0             5    3,101.10  Price
# 4318938  Doc2004055208            0             5    3,101.10  Price
# 4318975  Doc2004055208            0             5    2,797.93  Price
# 4829263  Doc2044033097            2             8       11.39  Price
# ...                ...          ...           ...         ...    ...
# 5018843  Doc2090060879            3             4      122.50  Price
# 5018849  Doc2090060879            3             4      450.80  Price
# 5018855  Doc2090060879            3             4      644.00  Price
# 5018861  Doc2090060879            3             4      315.00  Price
# 5018867  Doc2090060879            3             4      466.00  Price
# 5018873  Doc2090060879            3             4    1,768.00  Price
# 5018879  Doc2090060879            3             4    4,391.00  Price
# 5018885  Doc2090060879            3             4    1,129.00  Price
# 5018903  Doc2090060879            3             4    2,222.24  Price
# 5018909  Doc2090060879            3             4    1,694.60  Price
# 5059644  Doc2090637515           10             2    $ 30,604  Price
# 5062732  Doc2091386045           10             2    $ 30,604  Price
# 5065708  Doc2092943547           11             2    $ 30,604  Price
# 5076178  Doc2097174370            2             5       67.20  Price
# 5076183  Doc2097174370            2             8       80.00  Price
# 5076252  Doc2097174370            2             4       24.30  Price
# 5076255  Doc2097174370            2             5       25.30  Price
# 5076320  Doc2097174370            2             8       48.30  Price
# 5076348  Doc2097174370            2             5        9.50  Price
# 5076686  Doc2097174371            3             5       67.20  Price
# 5076691  Doc2097174371            3             8       80.00  Price
# 5076760  Doc2097174371            3             4       24.30  Price
# 5076763  Doc2097174371            3             5       25.30  Price
# 5076828  Doc2097174371            3             8       48.30  Price
# 5076856  Doc2097174371            3             5        9.50  Price
# 5077340  Doc2097314573            2             5        9.50  Price
# 5077866  Doc2097314575            1             5        9.50  Price
# 5078357  Doc2097314590            6             5        9.50  Price
# 5078740  Doc2097314590            8             4       30.00  Price
# 5078752  Doc2097314590            8             4       30.00  Price
#
# [205 rows x 5 columns]

# %%
df_Merge.to_csv(r'C:\Users\jrstrong\Desktop\temp\df_Merge.csv')

# %%
def preprocess(x):   
    df_ContractTable = pd.merge(df_Contract,
                            x,
                            left_on=['DocumentId','TableNumber','RowNumber'],
                            right_on=['DocumentId','TableNumber','RowNumber'],how='left')
    
    df_ContractTable.to_csv(r'C:\Users\jrstrong\Desktop\temp\final.csv', mode='a', header=False, index=False)

reader = pd.read_csv(r'C:\Users\jrstrong\Desktop\temp\df_Merge.csv', chunksize=1000)

for r in reader:
    preprocess(r)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-434ff7c6c3be> in <module>
#      10
#      11 for r in reader:
# ---> 12     preprocess(r)
#
# <ipython-input-5-434ff7c6c3be> in preprocess(x)
#       5                             right_on=['DocumentId','TableNumber','RowNumber'],how='left')
#       6
# ----> 7     df_ContractTable.to_csv(r'C:\Users\jrstrong\Desktop\temp\final.csv', mode='a', header=False, index=False)
#       8
#       9 reader = pd.read_csv(r'C:\Users\jrstrong\Desktop\temp\df_Merge.csv', chunksize=1000)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\csvs.py in save(self)
#     169                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     170
# --> 171             self._save()
#     172
#     173         finally:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\csvs.py in _save(self)
#     284                 break
#     285
# --> 286             self._save_chunk(start_i, end_i)
#     287
#     288     def _save_chunk(self, start_i, end_i):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         libwriters.write_csv_rows(self.data, ix, self.nlevels,
# --> 313                                   self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
df_Merge
# Out:
#                 spn  line_net_prc_USD_amt       supl_id   Supplier Id  \
# 0         781743-01               8003.00  1000006922.0  1000006922.0
# 1         781743-01               8003.00  1000006922.0  1000006922.0
# 2         781743-01               8003.00  1000006922.0  1000006922.0
# 3         781743-01               8003.00  1000006922.0  1000006922.0
# 4         781743-01               8599.00  1000006922.0  1000006922.0
# 5         781743-01               8599.00  1000006922.0  1000006922.0
# 6         781743-01               8599.00  1000006922.0  1000006922.0
# 7         781743-01               8599.00  1000006922.0  1000006922.0
# 8         781743-01               8464.92  1000006922.0  1000006922.0
# 9         781743-01               8464.92  1000006922.0  1000006922.0
# 10        781743-01               8464.92  1000006922.0  1000006922.0
# 11        781743-01               8464.92  1000006922.0  1000006922.0
# 12        781813-01               9860.76  1000006922.0  1000006922.0
# 13        781813-01               9860.76  1000006922.0  1000006922.0
# 14        781813-01               9860.76  1000006922.0  1000006922.0
# 15        781813-01               9860.76  1000006922.0  1000006922.0
# 16        G2681561D                690.00  1000021890.0  1000021890.0
# 17        G2686491D                997.00  1000021890.0  1000021890.0
# 18        G2686934D               3448.00  1000021890.0  1000021890.0
# 19       G2697572DP               3800.00  1000021890.0  1000021890.0
# 20       G2697572DP               3800.00  1000021890.0  1000021890.0
# 21       G2699574DP                637.00  1000021890.0  1000021890.0
# 22        778572-67               1217.00  1000006922.0  1000006922.0
# 23        778572-67               1217.00  1000006922.0  1000006922.0
# 24        778572-67               1217.00  1000006922.0  1000006922.0
# 25        778572-67               1217.00  1000006922.0  1000006922.0
# 26        778572-67               1963.83  1000006922.0  1000006922.0
# 27        778572-67               1963.83  1000006922.0  1000006922.0
# 28        778572-67               1963.83  1000006922.0  1000006922.0
# 29        778572-67               1963.83  1000006922.0  1000006922.0
# ..              ...                   ...           ...           ...
# 638           34402               1769.60  1000087195.0  1000087195.0
# 639           34402               1769.60  1000087195.0  1000087195.0
# 640           36499                108.64  1000087195.0  1000087195.0
# 641           36499                108.64  1000087195.0  1000087195.0
# 642           36499                108.64  1000087195.0  1000087195.0
# 643           36499                108.64  1000087195.0  1000087195.0
# 644           16815                464.06  1000087195.0  1000087195.0
# 645           16815                464.06  1000087195.0  1000087195.0
# 646           16815                464.06  1000087195.0  1000087195.0
# 647     351036-0240              30604.00  1000012793.0  1000012793.0
# 648     351036-0240              30604.00  1000012793.0  1000012793.0
# 649     351036-0240              30604.00  1000012793.0  1000012793.0
# 650  05-2275258C01D               1656.00  1000017314.0  1000017314.0
# 651  05-2845326573D                252.00  1000017314.0  1000017314.0
# 652    05-136432607                 28.60  1000017314.0  1000017314.0
# 653  05-1574258601D                517.00  1000017314.0  1000017314.0
# 654  05-2575326C04D               2981.00  1000017314.0  1000017314.0
# 655    05-2575326C2              51800.00  1000017314.0  1000017314.0
# 656  05-4014326C01D               1530.00  1000017314.0  1000017314.0
# 657  06-3852326603D                666.00  1000017314.0  1000017314.0
# 658    07-123532607                 15.00  1000017314.0  1000017314.0
# 659           16814                215.94  1000087195.0  1000087195.0
# 660           16814                215.94  1000087195.0  1000087195.0
# 661           16814                215.94  1000087195.0  1000087195.0
# 662        26243KCN                 87.18  1000087195.0  1000087195.0
# 663        26243KCN                 87.18  1000087195.0  1000087195.0
# 664        26243KCN                 87.18  1000087195.0  1000087195.0
# 665           29823               2184.00  1000087195.0  1000087195.0
# 666           29823               2184.00  1000087195.0  1000087195.0
# 667           29823               2184.00  1000087195.0  1000087195.0
#
#         DocumentId  TableNumber  RowNumber  ColumnNumber     ColumnValue  \
# 0    Doc2094002797            1          9             1       781743-01
# 1    Doc2094002799            1          9             1       781743-01
# 2    Doc2094002802            1          9             1       781743-01
# 3    Doc2096128745            1          9             1       781743-01
# 4    Doc2094002797            1          9             1       781743-01
# 5    Doc2094002799            1          9             1       781743-01
# 6    Doc2094002802            1          9             1       781743-01
# 7    Doc2096128745            1          9             1       781743-01
# 8    Doc2094002797            1          9             1       781743-01
# 9    Doc2094002799            1          9             1       781743-01
# 10   Doc2094002802            1          9             1       781743-01
# 11   Doc2096128745            1          9             1       781743-01
# 12   Doc2094002797            1          2             1       781813-01
# 13   Doc2094002799            1          2             1       781813-01
# 14   Doc2094002802            1          2             1       781813-01
# 15   Doc2096128745            1          2             1       781813-01
# 16   Doc1953414166            0          2             2       G2681561D
# 17   Doc1953414166            0         13             2       G2686491D
# 18   Doc1953414166            0         10             2       G2686934D
# 19   Doc1953414166            0         11             2      G2697572DP
# 20   Doc1953414166            0         42             2      G2697572DP
# 21   Doc1953414166            0         41             2      G2699574DP
# 22   Doc2094002797            1          7             1       778572-67
# 23   Doc2094002799            1          7             1       778572-67
# 24   Doc2094002802            1          7             1       778572-67
# 25   Doc2096128745            1          7             1       778572-67
# 26   Doc2094002797            1          7             1       778572-67
# 27   Doc2094002799            1          7             1       778572-67
# 28   Doc2094002802            1          7             1       778572-67
# 29   Doc2096128745            1          7             1       778572-67
# ..             ...          ...        ...           ...             ...
# 638  Doc2099419139            1          8             1           34402
# 639  Doc2099419139            1         21             1           34402
# 640  Doc2093676459            1         11             1           36499
# 641  Doc2093676459            1         27             1           36499
# 642  Doc2093676460            1         11             1           36499
# 643  Doc2099419139            1         11             1           36499
# 644  Doc2093676459            1         15             1           16815
# 645  Doc2093676460            1         15             1           16815
# 646  Doc2099419139            1         15             1           16815
# 647  Doc2090637515           10         10             0     351036-0240
# 648  Doc2091386045           10         10             0     351036-0240
# 649  Doc2092943547           11         10             0     351036-0240
# 650  Doc2044033097            2         11             2  05-2275258C01D
# 651  Doc2044033097            2          5             2  05-2845326573D
# 652  Doc2044033097            2         10             2    05-136432607
# 653  Doc2044033097            2          6             2  05-1574258601D
# 654  Doc2044033097            2         16             2  05-2575326C04D
# 655  Doc2044033097            2         17             2    05-2575326C2
# 656  Doc2044033097            2         26             2  05-4014326C01D
# 657  Doc2044033097            2         19             2  06-3852326603D
# 658  Doc2044033097            2         21             2    07-123532607
# 659  Doc2093676459            1         19             1           16814
# 660  Doc2093676460            1         19             1           16814
# 661  Doc2099419139            1         19             1           16814
# 662  Doc2093676459            1          2             1        26243KCN
# 663  Doc2093676460            1          2             1        26243KCN
# 664  Doc2099419139            1          2             1        26243KCN
# 665  Doc2093676459            1          4             1           29823
# 666  Doc2093676460            1          4             1           29823
# 667  Doc2099419139            1          4             1           29823
#
#     TableConfidence busns_org_prty_id  glbl_busns_org_prty_id
# 0                99      1000006922.0            1.000007e+09
# 1                99      1000006922.0            1.000007e+09
# 2                99      1000006922.0            1.000007e+09
# 3                99      1000006922.0            1.000007e+09
# 4                99      1000006922.0            1.000007e+09
# 5                99      1000006922.0            1.000007e+09
# 6                99      1000006922.0            1.000007e+09
# 7                99      1000006922.0            1.000007e+09
# 8                99      1000006922.0            1.000007e+09
# 9                99      1000006922.0            1.000007e+09
# 10               99      1000006922.0            1.000007e+09
# 11               99      1000006922.0            1.000007e+09
# 12               99      1000006922.0            1.000007e+09
# 13               99      1000006922.0            1.000007e+09
# 14               99      1000006922.0            1.000007e+09
# 15               99      1000006922.0            1.000007e+09
# 16               80      1000021890.0            1.000022e+09
# 17               80      1000021890.0            1.000022e+09
# 18               80      1000021890.0            1.000022e+09
# 19               80      1000021890.0            1.000022e+09
# 20               80      1000021890.0            1.000022e+09
# 21               80      1000021890.0            1.000022e+09
# 22               99      1000006922.0            1.000007e+09
# 23               99      1000006922.0            1.000007e+09
# 24               99      1000006922.0            1.000007e+09
# 25               99      1000006922.0            1.000007e+09
# 26               99      1000006922.0            1.000007e+09
# 27               99      1000006922.0            1.000007e+09
# 28               99      1000006922.0            1.000007e+09
# 29               99      1000006922.0            1.000007e+09
# ..              ...               ...                     ...
# 638              84      1000087195.0            1.000087e+09
# 639              84      1000087195.0            1.000087e+09
# 640             100      1000087195.0            1.000087e+09
# 641             100      1000087195.0            1.000087e+09
# 642              84      1000087195.0            1.000087e+09
# 643              84      1000087195.0            1.000087e+09
# 644             100      1000087195.0            1.000087e+09
# 645              84      1000087195.0            1.000087e+09
# 646              84      1000087195.0            1.000087e+09
# 647             100      1000012793.0            1.000013e+09
# 648              94      1000012793.0            1.000013e+09
# 649              94      1000012793.0            1.000013e+09
# 650              80      1000017314.0            1.000017e+09
# 651              80      1000017314.0            1.000017e+09
# 652              80      1000017314.0            1.000017e+09
# 653              80      1000017314.0            1.000017e+09
# 654              80      1000017314.0            1.000017e+09
# 655              80      1000017314.0            1.000017e+09
# 656              80      1000017314.0            1.000017e+09
# 657              80      1000017314.0            1.000017e+09
# 658              80      1000017314.0            1.000017e+09
# 659             100      1000087195.0            1.000087e+09
# 660              84      1000087195.0            1.000087e+09
# 661              84      1000087195.0            1.000087e+09
# 662             100      1000087195.0            1.000087e+09
# 663              84      1000087195.0            1.000087e+09
# 664              84      1000087195.0            1.000087e+09
# 665             100      1000087195.0            1.000087e+09
# 666              84      1000087195.0            1.000087e+09
# 667              84      1000087195.0            1.000087e+09
#
# [668 rows x 12 columns]
